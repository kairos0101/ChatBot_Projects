# %% [markdown]
# <a href="https://colab.research.google.com/github/kairos0101/ChatBot_Projects/blob/main/ChatBot_Meta_Llama_3_1_8B_Instruct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import userdata
import os
os.environ["HF_TOKEN"] = userdata.get('HuggingFace')

from huggingface_hub import login
login(token=os.environ["HF_TOKEN"])

# %%
# !pip install -U bitsandbytes

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline, BitsAndBytesConfig
import torch

model_id = "meta-llama/Meta-Llama-3.1-8B-Instruct"
#model_id = "meta-llama/Llama-3.1-8B"

quantization_config = BitsAndBytesConfig(load_in_8bit=True, llm_int8_enable_fp32_cpu_offload=True)

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id, quantization_config=quantization_config, torch_dtype="auto", device_map="auto").eval()

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Explain AI in one sentence."},
]

encoded_inputs = tokenizer.apply_chat_template(
    messages, add_generation_prompt=True, tokenize=True, return_tensors="pt"
).to(model.device)

outputs = model.generate(
    encoded_inputs['input_ids'], # Correctly access the input_ids tensor
    max_new_tokens=256, do_sample=True, temperature=0.6, top_p=0.9
)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Explain Computer Vision in one sentence."},
]

encoded_inputs = tokenizer.apply_chat_template(
    messages, add_generation_prompt=True, tokenize=True, return_tensors="pt"
).to(model.device)

outputs = model.generate(
    encoded_inputs['input_ids'], # Correctly access the input_ids tensor
    max_new_tokens=256, do_sample=True, temperature=0.6, top_p=0.9
)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Explain Machine Learning in a complete details."},
]

encoded_inputs = tokenizer.apply_chat_template(
    messages, add_generation_prompt=True, tokenize=True, return_tensors="pt"
).to(model.device)

outputs = model.generate(
    encoded_inputs['input_ids'], # Correctly access the input_ids tensor
    max_new_tokens=256, do_sample=True, temperature=0.6, top_p=0.9
)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Explain Philippine history using 2 to 5 paragraphs."},
]

encoded_inputs = tokenizer.apply_chat_template(
    messages, add_generation_prompt=True, tokenize=True, return_tensors="pt"
).to(model.device)

outputs = model.generate(
    encoded_inputs['input_ids'], # Correctly access the input_ids tensor
    max_new_tokens=256, do_sample=True, temperature=0.6, top_p=0.9
)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Explain World history in clear and complete details."},
]

encoded_inputs = tokenizer.apply_chat_template(
    messages, add_generation_prompt=True, tokenize=True, return_tensors="pt"
).to(model.device)

outputs = model.generate(
    encoded_inputs['input_ids'], # Correctly access the input_ids tensor
    max_new_tokens=512, do_sample=True, temperature=0.6, top_p=0.9
)
print(tokenizer.decode(outputs[0], skip_special_tokens=True))

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

# Assuming you have your trained model and tokenizer objects
# (e.g., loaded or fine-tuned from "microsoft/blenderbot-400M-distill")
# model = AutoModelForCausalLM.from_pretrained(...)
# tokenizer = AutoTokenizer.from_pretrained(...)

# Define the local directory path where you want to save the model
save_directory = "/content/my_chatbot_model"

# Save the model and tokenizer
model.save_pretrained(save_directory)
tokenizer.save_pretrained(save_directory)
